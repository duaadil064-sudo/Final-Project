# %%
# simple calculator

# Ask how many calculation
num_calculations = int(input("How many calculation: "))

# repeat calculation using for loop
for i in range(num_calculations):
  print(f"\ncalculation {i + 1}: ")

  # Get numbers
  num1 = float(input("Enter the first number: "))
  num2 = float(input("Enter the second number: "))

  print("choose an operator: ")
  print("1. Addition (+)")
  print("2. Subtraction (-)")
  print("3. Multiplication (*)")
  print("4. Division (/)")

  choice = input("Enter the number of an operator (1-4): ")

  # perform calculation based on choice
  if choice == '1':
        print("Result:", num1 + num2)
  elif choice == '2':
        print("Result:", num1 - num2)
  elif choice == '3':
        print("Result:", num1 * num2)
  elif choice == '4':
        if num2 == 0:
            print("Error: Cannot divide by zero!")
        else:
            print("Result:", num1 / num2)
  else:
      print("\nError: Invalid choice! Please enter 1, 2, 3, or 4.")
# Out:
# How many calculation: 1
#
# calculation 1:
# Enter the first number: 4
# Enter the second number: 4
# choose an operator:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# Enter the number of an operator (1-4): 5
# Error: Invalid choice! Please enter 1, 2, 3, or 4.
